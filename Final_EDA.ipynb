# %% [markdown]
# # Primary

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_primary = pd.read_csv('primary.csv')
len(df_primary.index)
# Out:
# /var/folders/9x/xjq8ll4n6y9099n53k2sttp40000gn/T/ipykernel_6750/438247923.py:1: DtypeWarning: Columns (6,7,9,26,37,40,59,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_primary = pd.read_csv('primary.csv')
# 56716

# %%
# Loop through each column
for column in df_primary.columns:
    # Calculate the number of missing values in the column
    missing_values_count = df_primary[column].isnull().sum()
    
    # Calculate the number of unique values in the column
    unique_values_count = df_primary[column].nunique()
    
    # Print the results
    print(f"Column: {column}")
    print(f"   Number of missing values: {missing_values_count}")
    print(f"   Number of unique values: {unique_values_count}")
    print()
# Out:
# Column: Source_ID
#    Number of missing values: 0
#    Number of unique values: 13459
#
# Column: Source_Name
#    Number of missing values: 0
#    Number of unique values: 12413
#
# Column: Status_Code
#    Number of missing values: 0
#    Number of unique values: 3
#
# Column: Status_Description
#    Number of missing values: 0
#    Number of unique values: 3
#
# Column: Type_Code
#    Number of missing values: 0
#    Number of unique values: 12
#
# Column: Type_Desc
#    Number of missing values: 0
#    Number of unique values: 10
#
# Column: Address
#    Number of missing values: 51124
#    Number of unique values: 5259
#
# Column: City
#    Number of missing values: 51074
#    Number of unique values: 2984
#
# Column: State_Abbr
#    Number of missing values: 0
#    Number of unique values: 59
#
# Column: Postal_Code
#    Number of missing values: 51076
#    Number of unique values: 5236
#
# Column: Degree_of_Shortage
#    Number of missing values: 5393
#    Number of unique values: 35
#
# Column: Designation_Date
#    Number of missing values: 0
#    Number of unique values: 3576
#
# Column: Designation_Last_Update_Date
#    Number of missing values: 0
#    Number of unique values: 1664
#
# Column: Designation_Pop
#    Number of missing values: 4126
#    Number of unique values: 7432
#
# Column: Estimated_Underserved_Pop
#    Number of missing values: 6106
#    Number of unique values: 5759
#
# Column: Estimated_Served_Pop
#    Number of missing values: 6103
#    Number of unique values: 1609
#
# Column: Formal_Ratio
#    Number of missing values: 13174
#    Number of unique values: 4363
#
# Column: Total_FTE_Clinicians
#    Number of missing values: 5233
#    Number of unique values: 1347
#
# Column: Metropolitan_Indicator_Code
#    Number of missing values: 0
#    Number of unique values: 4
#
# Column: Metropolitan_Indicator_Desc
#    Number of missing values: 0
#    Number of unique values: 4
#
# Column: Provider_Ratio_Goal
#    Number of missing values: 5089
#    Number of unique values: 4
#
# Column: Percent_Pop_Below_Poverty
#    Number of missing values: 16196
#    Number of unique values: 503
#
# Column: HPSA_Score
#    Number of missing values: 0
#    Number of unique values: 26
#
# Column: HPSA_Shortage
#    Number of missing values: 19663
#    Number of unique values: 1436
#
# Column: Discipline_Class_Num
#    Number of missing values: 0
#    Number of unique values: 1
#
# Column: Discipline_Class_Desc
#    Number of missing values: 0
#    Number of unique values: 1
#
# Column: Component_Source_ID
#    Number of missing values: 50730
#    Number of unique values: 5986
#
# Column: Component_Source_Name
#    Number of missing values: 0
#    Number of unique values: 24997
#
# Column: Component_Status_Code
#    Number of missing values: 0
#    Number of unique values: 4
#
# Column: Component_Status_Desc
#    Number of missing values: 0
#    Number of unique values: 4
#
# Column: Component_Type_Code
#    Number of missing values: 0
#    Number of unique values: 4
#
# Column: Component_Type_Desc
#    Number of missing values: 0
#    Number of unique values: 4
#
# Column: Component_State_Abbr
#    Number of missing values: 5986
#    Number of unique values: 59
#
# Column: Component_Postal_Code
#    Number of missing values: 56716
#    Number of unique values: 0
#
# Column: Component_Designation_Date
#    Number of missing values: 5986
#    Number of unique values: 2772
#
# Column: Component_Designation_Date_String
#    Number of missing values: 5986
#    Number of unique values: 2772
#
# Column: Component_Designation_Last_Update_Date
#    Number of missing values: 5986
#    Number of unique values: 1402
#
# Column: Geography_ID
#    Number of missing values: 0
#    Number of unique values: 34008
#
# Column: CountyFIPS
#    Number of missing values: 346
#    Number of unique values: 337
#
# Column: County_Name
#    Number of missing values: 0
#    Number of unique values: 1935
#
# Column: StateCountyFIPS
#    Number of missing values: 1
#    Number of unique values: 4968
#
# Column: State_FIPS
#    Number of missing values: 0
#    Number of unique values: 59
#
# Column: State_Abbr_2
#    Number of missing values: 0
#    Number of unique values: 59
#
# Column: State_Name
#    Number of missing values: 0
#    Number of unique values: 59
#
# Column: Primary_State_Name
#    Number of missing values: 0
#    Number of unique values: 59
#
# Column: Primary_State_FIPS
#    Number of missing values: 0
#    Number of unique values: 59
#
# Column: Primary_HHS_Region_Name
#    Number of missing values: 0
#    Number of unique values: 10
#
# Column: US_Mexico_Border_County
#    Number of missing values: 0
#    Number of unique values: 3
#
# Column: US_Mexico_Border_100km
#    Number of missing values: 0
#    Number of unique values: 3
#
# Column: Data_Warehouse_Record_Create_Date
#    Number of missing values: 0
#    Number of unique values: 1
#
# Column: Data_Warehouse_Record_Create_Date_Text
#    Number of missing values: 0
#    Number of unique values: 1
#
# Column: HPSA_Name
#    Number of missing values: 0
#    Number of unique values: 12255
#
# Column: HPSA_Component_Name
#    Number of missing values: 0
#    Number of unique values: 24918
#
# Column: Break_in_Designation
#    Number of missing values: 0
#    Number of unique values: 1
#
# Column: Geocoding_Primary_X
#    Number of missing values: 50730
#    Number of unique values: 5359
#
# Column: Geocoding_Primary_Y
#    Number of missing values: 50730
#    Number of unique values: 5361
#
# Column: HPSA_Pop_Type_Code
#    Number of missing values: 6303
#    Number of unique values: 12
#
# Column: HPSA_Pop_Type_Desc
#    Number of missing values: 5986
#    Number of unique values: 13
#
# Column: HPSA_Resident_Civilian_Pop
#    Number of missing values: 34769
#    Number of unique values: 2077
#
# Column: Common_City_Name_with_State_Abbr
#    Number of missing values: 51074
#    Number of unique values: 2984
#
# Column: Common_Postal_Code
#    Number of missing values: 51076
#    Number of unique values: 4046
#
# Column: Common_County_Name
#    Number of missing values: 0
#    Number of unique values: 3173
#
# Column: Common_StateCounty_FIPS
#    Number of missing values: 348
#    Number of unique values: 3172
#
# Column: Common_State_Abbr
#    Number of missing values: 0
#    Number of unique values: 59
#
# Column: Common_State_Name
#    Number of missing values: 0
#    Number of unique values: 59
#
# Column: Common_State_FIPS
#    Number of missing values: 0
#    Number of unique values: 59
#
# Column: Common_Region_Name
#    Number of missing values: 0
#    Number of unique values: 10
#
# Column: HPSA_Withdrawn_Date
#    Number of missing values: 22992
#    Number of unique values: 1260
#
# Column: HPSA_Withdrawn_Date_String
#    Number of missing values: 22992
#    Number of unique values: 1260
#
# Column: Provider_Type
#    Number of missing values: 5986
#    Number of unique values: 1
#
# Column: Rural_Status_Code
#    Number of missing values: 16559
#    Number of unique values: 5
#
# Column: Rural_Status_Desc
#    Number of missing values: 16559
#    Number of unique values: 5
#
# Column: HPSA_Designation_Pop_Type_Desc
#    Number of missing values: 0
#    Number of unique values: 20
#
# Column: BHCMIS_OrgID
#    Number of missing values: 55144
#    Number of unique values: 1532

# %%
# List of columns to keep
keep_columns = ['Source_ID', 'Status_Description', 'Type_Desc',
                   'State_Abbr', 'Degree_of_Shortage', 'Designation_Date',
                   'Designation_Last_Update_Date', 'Designation_Pop',
                   'Estimated_Underserved_Pop', 'Estimated_Served_Pop',
                   'Total_FTE_Clinicians', 'Metropolitan_Indicator_Desc',
                   'Percent_Pop_Below_Poverty', 'HPSA_Score', 'HPSA_Shortage',
                   'Component_Source_Name', 'Component_Status_Desc', 'Component_Type_Desc',
                   'County_Name', 'StateCountyFIPS', 'Primary_HHS_Region_Name',
                   'US_Mexico_Border_County', 'HPSA_Name', 'HPSA_Component_Name',
                   'HPSA_Pop_Type_Code', 'HPSA_Pop_Type_Desc', 'Rural_Status_Desc',
                   'HPSA_Designation_Pop_Type_Desc']

# Update DataFrame to include only the specified columns
df_primary = df_primary[keep_columns]

df_primary
# Out:
#         Source_ID Status_Description  \
# 0      1569995651         Designated
# 1      1469994698         Designated
# 2      1469994687         Designated
# 3      141999413V         Designated
# 4      14099940N2         Designated
# ...           ...                ...
# 56711  1566948303         Designated
# 56712  1565158613         Designated
# 56713  1563118211         Designated
# 56714  1562598744         Designated
# 56715  1562598744         Designated
#
#                                            Type_Desc State_Abbr  \
# 0      Indian, Tribal and Urban Indian Organizations         WY
# 1      Indian, Tribal and Urban Indian Organizations         SD
# 2      Indian, Tribal and Urban Indian Organizations         SD
# 3      Indian, Tribal and Urban Indian Organizations         OR
# 4      Indian, Tribal and Urban Indian Organizations         OK
# ...                                              ...        ...
# 56711                                Geographic HPSA         WY
# 56712                                Geographic HPSA         WY
# 56713                                Geographic HPSA         WY
# 56714                                Geographic HPSA         WY
# 56715                                Geographic HPSA         WY
#
#       Degree_of_Shortage Designation_Date Designation_Last_Update_Date  \
# 0                    NaN       2006-03-01                   2011-07-27
# 1                    NaN       2009-08-01                   2011-06-27
# 2                    NaN       2002-10-26                   2002-10-26
# 3                    NaN       2007-12-01                   2007-12-01
# 4                    NaN       2002-10-26                   2011-08-02
# ...                  ...              ...                          ...
# 56711     Not applicable       1988-06-28                   2017-10-28
# 56712     Not applicable       1992-11-30                   2017-10-28
# 56713     Not applicable       1995-05-01                   2017-10-28
# 56714     Not applicable       1984-03-14                   2017-10-28
# 56715     Not applicable       1984-03-14                   2017-10-28
#
#        Designation_Pop  Estimated_Underserved_Pop  Estimated_Served_Pop  ...  \
# 0                  NaN                        NaN                   NaN  ...
# 1                  NaN                        NaN                   NaN  ...
# 2                  NaN                        NaN                   NaN  ...
# 3                  NaN                        NaN                   NaN  ...
# 4                  1.0                        NaN                   NaN  ...
# ...                ...                        ...                   ...  ...
# 56711           1532.0                     1532.0                   0.0  ...
# 56712            858.0                      858.0                   0.0  ...
# 56713           3357.0                     3357.0                   0.0  ...
# 56714           5361.0                     1301.0                4060.0  ...
# 56715           5361.0                     1301.0                4060.0  ...
#
#         County_Name StateCountyFIPS  Primary_HHS_Region_Name  \
# 0           Fremont           56013              Region VIII
# 1            Corson           46031              Region VIII
# 2       Charles Mix           46023              Region VIII
# 3         Multnomah           41051                 Region X
# 4      Pottawatomie           40125                Region VI
# ...             ...             ...                      ...
# 56711       Fremont           56013              Region VIII
# 56712       Johnson           56019              Region VIII
# 56713       Laramie           56021              Region VIII
# 56714       Lincoln           56023              Region VIII
# 56715       Lincoln           56023              Region VIII
#
#        US_Mexico_Border_County                                    HPSA_Name  \
# 0                            N        Ft. Washakie PHS Indian Health Center
# 1                            N  McLaughlin PHS Indian Medical/Dental Clinic
# 2                            N                   Wagner PHS Indian Hospital
# 3                            N                         Portland Area Office
# 4                            N                        Shawnee Health Center
# ...                        ...                                          ...
# 56711                        N                                       Dubois
# 56712                        N                          Kaycee Service Area
# 56713                        N                                  Pine Bluffs
# 56714                        N                     Kemmerer (East and West)
# 56715                        N                     Kemmerer (East and West)
#
#                                HPSA_Component_Name HPSA_Pop_Type_Code  \
# 0            Ft. Washakie PHS Indian Health Center                NaN
# 1      McLaughlin PHS Indian Medical/Dental Clinic                NaN
# 2                       Wagner PHS Indian Hospital                NaN
# 3                             Portland Area Office                NaN
# 4                            Shawnee Health Center                NaN
# ...                                            ...                ...
# 56711                                   Dubois CCD                TRC
# 56712                                   Kaycee CCD                TRC
# 56713                              Pine Bluffs CCD                TRC
# 56714                            Kemmerer East CCD                TRC
# 56715                            Kemmerer West CCD                TRC
#
#           HPSA_Pop_Type_Desc Rural_Status_Desc  \
# 0                        NaN             Rural
# 1                        NaN             Rural
# 2                        NaN             Rural
# 3                        NaN         Non-Rural
# 4                        NaN             Rural
# ...                      ...               ...
# 56711  Geographic Population             Rural
# 56712  Geographic Population             Rural
# 56713  Geographic Population             Rural
# 56714  Geographic Population             Rural
# 56715  Geographic Population             Rural
#
#                       HPSA_Designation_Pop_Type_Desc
# 0      Indian, Tribal and Urban Indian Organizations
# 1      Indian, Tribal and Urban Indian Organizations
# 2      Indian, Tribal and Urban Indian Organizations
# 3      Indian, Tribal and Urban Indian Organizations
# 4      Indian, Tribal and Urban Indian Organizations
# ...                                              ...
# 56711                          Geographic Population
# 56712                          Geographic Population
# 56713                          Geographic Population
# 56714                          Geographic Population
# 56715                          Geographic Population
#
# [56716 rows x 28 columns]

# %%
states_to_exclude = ['AS', 'GU', 'MP', 'PR', 'TT', 'VI', 'MH', 'PW', 'FM']

# Filter out rows with specified states
df_primary = df_primary[~df_primary['State_Abbr'].isin(states_to_exclude)]
df_primary
# Out:
#         Source_ID Status_Description  \
# 0      1569995651         Designated
# 1      1469994698         Designated
# 2      1469994687         Designated
# 3      141999413V         Designated
# 4      14099940N2         Designated
# ...           ...                ...
# 56711  1566948303         Designated
# 56712  1565158613         Designated
# 56713  1563118211         Designated
# 56714  1562598744         Designated
# 56715  1562598744         Designated
#
#                                            Type_Desc State_Abbr  \
# 0      Indian, Tribal and Urban Indian Organizations         WY
# 1      Indian, Tribal and Urban Indian Organizations         SD
# 2      Indian, Tribal and Urban Indian Organizations         SD
# 3      Indian, Tribal and Urban Indian Organizations         OR
# 4      Indian, Tribal and Urban Indian Organizations         OK
# ...                                              ...        ...
# 56711                                Geographic HPSA         WY
# 56712                                Geographic HPSA         WY
# 56713                                Geographic HPSA         WY
# 56714                                Geographic HPSA         WY
# 56715                                Geographic HPSA         WY
#
#       Degree_of_Shortage Designation_Date Designation_Last_Update_Date  \
# 0                    NaN       2006-03-01                   2011-07-27
# 1                    NaN       2009-08-01                   2011-06-27
# 2                    NaN       2002-10-26                   2002-10-26
# 3                    NaN       2007-12-01                   2007-12-01
# 4                    NaN       2002-10-26                   2011-08-02
# ...                  ...              ...                          ...
# 56711     Not applicable       1988-06-28                   2017-10-28
# 56712     Not applicable       1992-11-30                   2017-10-28
# 56713     Not applicable       1995-05-01                   2017-10-28
# 56714     Not applicable       1984-03-14                   2017-10-28
# 56715     Not applicable       1984-03-14                   2017-10-28
#
#        Designation_Pop  Estimated_Underserved_Pop  Estimated_Served_Pop  ...  \
# 0                  NaN                        NaN                   NaN  ...
# 1                  NaN                        NaN                   NaN  ...
# 2                  NaN                        NaN                   NaN  ...
# 3                  NaN                        NaN                   NaN  ...
# 4                  1.0                        NaN                   NaN  ...
# ...                ...                        ...                   ...  ...
# 56711           1532.0                     1532.0                   0.0  ...
# 56712            858.0                      858.0                   0.0  ...
# 56713           3357.0                     3357.0                   0.0  ...
# 56714           5361.0                     1301.0                4060.0  ...
# 56715           5361.0                     1301.0                4060.0  ...
#
#         County_Name StateCountyFIPS  Primary_HHS_Region_Name  \
# 0           Fremont           56013              Region VIII
# 1            Corson           46031              Region VIII
# 2       Charles Mix           46023              Region VIII
# 3         Multnomah           41051                 Region X
# 4      Pottawatomie           40125                Region VI
# ...             ...             ...                      ...
# 56711       Fremont           56013              Region VIII
# 56712       Johnson           56019              Region VIII
# 56713       Laramie           56021              Region VIII
# 56714       Lincoln           56023              Region VIII
# 56715       Lincoln           56023              Region VIII
#
#        US_Mexico_Border_County                                    HPSA_Name  \
# 0                            N        Ft. Washakie PHS Indian Health Center
# 1                            N  McLaughlin PHS Indian Medical/Dental Clinic
# 2                            N                   Wagner PHS Indian Hospital
# 3                            N                         Portland Area Office
# 4                            N                        Shawnee Health Center
# ...                        ...                                          ...
# 56711                        N                                       Dubois
# 56712                        N                          Kaycee Service Area
# 56713                        N                                  Pine Bluffs
# 56714                        N                     Kemmerer (East and West)
# 56715                        N                     Kemmerer (East and West)
#
#                                HPSA_Component_Name HPSA_Pop_Type_Code  \
# 0            Ft. Washakie PHS Indian Health Center                NaN
# 1      McLaughlin PHS Indian Medical/Dental Clinic                NaN
# 2                       Wagner PHS Indian Hospital                NaN
# 3                             Portland Area Office                NaN
# 4                            Shawnee Health Center                NaN
# ...                                            ...                ...
# 56711                                   Dubois CCD                TRC
# 56712                                   Kaycee CCD                TRC
# 56713                              Pine Bluffs CCD                TRC
# 56714                            Kemmerer East CCD                TRC
# 56715                            Kemmerer West CCD                TRC
#
#           HPSA_Pop_Type_Desc Rural_Status_Desc  \
# 0                        NaN             Rural
# 1                        NaN             Rural
# 2                        NaN             Rural
# 3                        NaN         Non-Rural
# 4                        NaN             Rural
# ...                      ...               ...
# 56711  Geographic Population             Rural
# 56712  Geographic Population             Rural
# 56713  Geographic Population             Rural
# 56714  Geographic Population             Rural
# 56715  Geographic Population             Rural
#
#                       HPSA_Designation_Pop_Type_Desc
# 0      Indian, Tribal and Urban Indian Organizations
# 1      Indian, Tribal and Urban Indian Organizations
# 2      Indian, Tribal and Urban Indian Organizations
# 3      Indian, Tribal and Urban Indian Organizations
# 4      Indian, Tribal and Urban Indian Organizations
# ...                                              ...
# 56711                          Geographic Population
# 56712                          Geographic Population
# 56713                          Geographic Population
# 56714                          Geographic Population
# 56715                          Geographic Population
#
# [56344 rows x 28 columns]

# %%
# remove missing rows
# Replace the column names if they are different in your dataset
columns_to_check = ['Degree_of_Shortage', 'Designation_Pop', 'Estimated_Underserved_Pop',
                    'Estimated_Served_Pop', 'Total_FTE_Clinicians', 'Percent_Pop_Below_Poverty',
                    'HPSA_Shortage', 'HPSA_Pop_Type_Code', 'HPSA_Pop_Type_Desc', 'Rural_Status_Desc']

# Drop rows with missing values in the specified columns
df_primary = df_primary.dropna(subset=columns_to_check)

df_primary
# Out:
#         Source_ID Status_Description        Type_Desc State_Abbr  \
# 6007   1029990222          Withdrawn  Geographic HPSA         AK
# 6008   1029990222          Withdrawn  Geographic HPSA         AK
# 6009   1029990222          Withdrawn  Geographic HPSA         AK
# 6010   1029990222          Withdrawn  Geographic HPSA         AK
# 6011   1029990223          Withdrawn  Geographic HPSA         AK
# ...           ...                ...              ...        ...
# 56711  1566948303         Designated  Geographic HPSA         WY
# 56712  1565158613         Designated  Geographic HPSA         WY
# 56713  1563118211         Designated  Geographic HPSA         WY
# 56714  1562598744         Designated  Geographic HPSA         WY
# 56715  1562598744         Designated  Geographic HPSA         WY
#
#       Degree_of_Shortage Designation_Date Designation_Last_Update_Date  \
# 6007      Not applicable       1993-11-12                   2018-07-02
# 6008      Not applicable       1993-11-12                   2018-07-02
# 6009      Not applicable       1993-11-12                   2018-07-02
# 6010      Not applicable       1993-11-12                   2018-07-02
# 6011      Not applicable       1993-11-22                   1999-09-20
# ...                  ...              ...                          ...
# 56711     Not applicable       1988-06-28                   2017-10-28
# 56712     Not applicable       1992-11-30                   2017-10-28
# 56713     Not applicable       1995-05-01                   2017-10-28
# 56714     Not applicable       1984-03-14                   2017-10-28
# 56715     Not applicable       1984-03-14                   2017-10-28
#
#        Designation_Pop  Estimated_Underserved_Pop  Estimated_Served_Pop  ...  \
# 6007            9120.0                     7720.0                1400.0  ...
# 6008            9120.0                     7720.0                1400.0  ...
# 6009            9120.0                     7720.0                1400.0  ...
# 6010            9120.0                     7720.0                1400.0  ...
# 6011            4703.0                     1203.0                3500.0  ...
# ...                ...                        ...                   ...  ...
# 56711           1532.0                     1532.0                   0.0  ...
# 56712            858.0                      858.0                   0.0  ...
# 56713           3357.0                     3357.0                   0.0  ...
# 56714           5361.0                     1301.0                4060.0  ...
# 56715           5361.0                     1301.0                4060.0  ...
#
#              County_Name StateCountyFIPS  Primary_HHS_Region_Name  \
# 6007   Matanuska-Susitna            2170                 Region X
# 6008   Matanuska-Susitna            2170                 Region X
# 6009   Matanuska-Susitna            2170                 Region X
# 6010   Matanuska-Susitna            2170                 Region X
# 6011   Matanuska-Susitna            2170                 Region X
# ...                  ...             ...                      ...
# 56711            Fremont           56013              Region VIII
# 56712            Johnson           56019              Region VIII
# 56713            Laramie           56021              Region VIII
# 56714            Lincoln           56023              Region VIII
# 56715            Lincoln           56023              Region VIII
#
#        US_Mexico_Border_County                 HPSA_Name HPSA_Component_Name  \
# 6007                         N   Talkeetna/Trapper Creek                1.01
# 6008                         N   Talkeetna/Trapper Creek                1.02
# 6009                         N   Talkeetna/Trapper Creek                4.02
# 6010                         N   Talkeetna/Trapper Creek                4.01
# 6011                         N           Valdez/Whittier                4.02
# ...                        ...                       ...                 ...
# 56711                        N                    Dubois          Dubois CCD
# 56712                        N       Kaycee Service Area          Kaycee CCD
# 56713                        N               Pine Bluffs     Pine Bluffs CCD
# 56714                        N  Kemmerer (East and West)   Kemmerer East CCD
# 56715                        N  Kemmerer (East and West)   Kemmerer West CCD
#
#       HPSA_Pop_Type_Code     HPSA_Pop_Type_Desc Rural_Status_Desc  \
# 6007                 TRC  Geographic Population             Rural
# 6008                 TRC  Geographic Population             Rural
# 6009                 TRC  Geographic Population             Rural
# 6010                 TRC  Geographic Population             Rural
# 6011                 TRC  Geographic Population             Rural
# ...                  ...                    ...               ...
# 56711                TRC  Geographic Population             Rural
# 56712                TRC  Geographic Population             Rural
# 56713                TRC  Geographic Population             Rural
# 56714                TRC  Geographic Population             Rural
# 56715                TRC  Geographic Population             Rural
#
#       HPSA_Designation_Pop_Type_Desc
# 6007           Geographic Population
# 6008           Geographic Population
# 6009           Geographic Population
# 6010           Geographic Population
# 6011           Geographic Population
# ...                              ...
# 56711          Geographic Population
# 56712          Geographic Population
# 56713          Geographic Population
# 56714          Geographic Population
# 56715          Geographic Population
#
# [22555 rows x 28 columns]

# %%
# Loop through each column
for column in df_primary.columns:
    # Calculate the number of missing values in the column
    missing_values_count = df_primary[column].isnull().sum()
    
    # Calculate the number of unique values in the column
    unique_values_count = df_primary[column].nunique()
    
    # Print the results
    print(f"Column: {column}")
    print(f"   Number of missing values: {missing_values_count}")
    print(f"   Number of unique values: {unique_values_count}")
    print()
# Out:
# Column: Source_ID
#    Number of missing values: 0
#    Number of unique values: 3695
#
# Column: Status_Description
#    Number of missing values: 0
#    Number of unique values: 3
#
# Column: Type_Desc
#    Number of missing values: 0
#    Number of unique values: 3
#
# Column: State_Abbr
#    Number of missing values: 0
#    Number of unique values: 50
#
# Column: Degree_of_Shortage
#    Number of missing values: 0
#    Number of unique values: 1
#
# Column: Designation_Date
#    Number of missing values: 0
#    Number of unique values: 1695
#
# Column: Designation_Last_Update_Date
#    Number of missing values: 0
#    Number of unique values: 210
#
# Column: Designation_Pop
#    Number of missing values: 0
#    Number of unique values: 3521
#
# Column: Estimated_Underserved_Pop
#    Number of missing values: 0
#    Number of unique values: 3367
#
# Column: Estimated_Served_Pop
#    Number of missing values: 0
#    Number of unique values: 1369
#
# Column: Total_FTE_Clinicians
#    Number of missing values: 0
#    Number of unique values: 1180
#
# Column: Metropolitan_Indicator_Desc
#    Number of missing values: 0
#    Number of unique values: 4
#
# Column: Percent_Pop_Below_Poverty
#    Number of missing values: 0
#    Number of unique values: 426
#
# Column: HPSA_Score
#    Number of missing values: 0
#    Number of unique values: 24
#
# Column: HPSA_Shortage
#    Number of missing values: 0
#    Number of unique values: 1279
#
# Column: Component_Source_Name
#    Number of missing values: 0
#    Number of unique values: 11640
#
# Column: Component_Status_Desc
#    Number of missing values: 0
#    Number of unique values: 3
#
# Column: Component_Type_Desc
#    Number of missing values: 0
#    Number of unique values: 3
#
# Column: County_Name
#    Number of missing values: 0
#    Number of unique values: 1624
#
# Column: StateCountyFIPS
#    Number of missing values: 0
#    Number of unique values: 2657
#
# Column: Primary_HHS_Region_Name
#    Number of missing values: 0
#    Number of unique values: 10
#
# Column: US_Mexico_Border_County
#    Number of missing values: 0
#    Number of unique values: 2
#
# Column: HPSA_Name
#    Number of missing values: 0
#    Number of unique values: 3206
#
# Column: HPSA_Component_Name
#    Number of missing values: 0
#    Number of unique values: 11640
#
# Column: HPSA_Pop_Type_Code
#    Number of missing values: 0
#    Number of unique values: 12
#
# Column: HPSA_Pop_Type_Desc
#    Number of missing values: 0
#    Number of unique values: 12
#
# Column: Rural_Status_Desc
#    Number of missing values: 0
#    Number of unique values: 5
#
# Column: HPSA_Designation_Pop_Type_Desc
#    Number of missing values: 0
#    Number of unique values: 12

# %%
# Replace 'State_Abbr' with the actual column name if it's different
primary_state_abbr_counts = df_primary['State_Abbr'].value_counts()

# Get the top 10 states
primary_top_10_states = primary_state_abbr_counts.head(10)

# Plotting
plt.figure(figsize=(10, 6))
primary_top_10_states.plot(kind='bar', color='skyblue')
plt.title('Top 10 States Based on State Abbreviation Counts')
plt.xlabel('State Abbreviation')
plt.ylabel('Count')
plt.show()

# %%
primary_top_regions = df_primary['Primary_HHS_Region_Name'].value_counts()
primary_top_regions
# Out:
# Primary_HHS_Region_Name
# Region IX      4597
# Region V       4567
# Region IV      3806
# Region II      2579
# Region III     1967
# Region VI      1478
# Region VIII    1191
# Region VII      900
# Region X        848
# Region I        622
# Name: count, dtype: int64

# %%
primary_rural_status_count = df_primary['Rural_Status_Desc'].value_counts()
primary_rural_status_count
# Out:
# Rural_Status_Desc
# Non-Rural          15703
# Rural               6389
# Partially Rural      447
# Not Applicable        12
# Unknown                4
# Name: count, dtype: int64

# %%
# Assuming 'df_cleaned' is your cleaned DataFrame
# Replace 'HPSA_Score' with the actual column name if it's different
primary_average_hpsa_score = df_primary['HPSA_Score'].mean()
primary_average_hpsa_score

hpsa_scores = df_primary['HPSA_Score']

# Plotting
plt.figure(figsize=(10, 6))
plt.hist(hpsa_scores, bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of HPSA Scores')
plt.xlabel('HPSA Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Replace 'HPSA_Score' and 'State_Abbr' with the actual column names if they're different
primary_average_hpsa_by_state = df_primary.groupby('State_Abbr')['HPSA_Score'].mean().nlargest(5)

# Plotting
plt.figure(figsize=(12, 8))
primary_average_hpsa_by_state.plot(kind='bar', color='skyblue')
plt.title('Top 5 Average HPSA Scores by State')
plt.xlabel('State Abbreviation')
plt.ylabel('Average HPSA Score')
plt.show()

# %%
# Replace 'HPSA_Score' and 'State_Abbr' with the actual column names if they're different
primary_5_lowest = df_primary.groupby('State_Abbr')['HPSA_Score'].mean().nsmallest(5)

# Plotting
plt.figure(figsize=(12, 8))
primary_5_lowest.plot(kind='bar', color='skyblue')
plt.title('Lowest 5 Average HPSA Scores by State')
plt.xlabel('State Abbreviation')
plt.ylabel('Average HPSA Score')
plt.show()

# %%
primary_average_hpsa_shortage = df_primary['HPSA_Shortage'].mean()
primary_average_hpsa_shortage
# Out:
# 12.10626560407892

# %%
primary_hpsa_shortage = df_primary['HPSA_Shortage']

# Plotting
plt.figure(figsize=(10, 6))
plt.hist(primary_hpsa_shortage, bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of HPSA Shortage')
plt.xlabel('HPSA Shortage')
plt.ylabel('Frequency')
plt.show()

# %%
# Replace 'HPSA_Shortage' and 'Primary_HHS_Region_Name' with the actual column names if they're different
hpsa_region_sum = df_primary.groupby('Primary_HHS_Region_Name')['HPSA_Shortage'].sum()

# Plotting
hpsa_region_sum.plot(kind='bar', figsize=(12, 8), color='skyblue')
plt.title('Total HPSA_Shortage Counts per Primary_HHS_Region_Name')
plt.xlabel('Primary_HHS_Region_Name')
plt.ylabel('Total Count')
plt.show()

# %%
primary_avg_poverty = df_primary['Percent_Pop_Below_Poverty'].mean()
primary_avg_poverty
# Out:
# 22.098146752383062

# %%
# Replace 'HPSA_Score' and 'State_Abbr' with the actual column names if they're different
primary_avg_poverty_by_state = df_primary.groupby('State_Abbr')['Percent_Pop_Below_Poverty'].mean()

# Find the top 5 states with the highest and lowest average scores
primary_top_5_poverty = primary_avg_poverty_by_state.nlargest(5)
primary_lowest_5_poverty = primary_avg_poverty_by_state.nsmallest(5)

# Combine the two sets of states
primary_poverty_states = pd.concat([primary_top_5_poverty, primary_lowest_5_poverty])

# Plotting
plt.figure(figsize=(12, 8))
primary_poverty_states.plot(kind='bar', color='skyblue')
plt.title('Top 5 States with Highest and Lowest Average Percentage of Population Below Poverty')
plt.xlabel('State Abbreviation')
plt.ylabel('Average Poverty Percentage')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define your custom color scheme using hex codes
color_scheme = ['#ecb462', '#d35635', '#4da1ad']  # Replace with your own hex codes

# Create a custom colormap
cmap = LinearSegmentedColormap.from_list('custom_cmap', color_scheme)

# Assuming df_primary is your DataFrame and already contains the necessary data
# Selecting only the specified columns
columns = ['Designation_Pop', 'Estimated_Underserved_Pop', 'Estimated_Served_Pop', 
           'Total_FTE_Clinicians', 'Percent_Pop_Below_Poverty', 'HPSA_Score', 'HPSA_Shortage']
df_selected = df_primary[columns]

# Creating a correlation matrix
correlation_matrix = df_selected.corr()

# Plotting the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap=cmap)
plt.title("Correlation Matrix")
plt.savefig('heatmap_transparent_background.png', bbox_inches='tight', pad_inches=0.0, transparent=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define your custom color scheme
palette = ['#ecb462', '#d35635', '#4da1ad', '#212121']

# Assuming 'df_primary' is your DataFrame and it contains 'Metropolitan_Indicator_Desc' column
# Filter out 'Unknown' and 'Not Applicable' from the 'Metropolitan_Indicator_Desc' column
df_filtered = df_primary[~df_primary['Metropolitan_Indicator_Desc'].isin(['Unknown', 'Not Applicable'])]

# Calculate the average HPSA_Score for each Metropolitan Indicator Description
avg_hpsa_score_per_metropolitan = df_filtered.groupby('Metropolitan_Indicator_Desc')['Designation_Pop'].mean().reset_index()

# Create a bar chart
plt.figure(figsize=(12, 7))
sns.barplot(x='Metropolitan_Indicator_Desc', y='Designation_Pop', data=avg_hpsa_score_per_metropolitan, palette=palette)

# Set the title and labels
plt.title('Average HPSA Score by Metropolitan Indicator Description')
plt.xlabel('Metropolitan Indicator Description')
plt.ylabel('Average HPSA Score')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()

# Save the figure with a transparent background
plt.savefig('avg_hpsa_score_per_metropolitan.png', bbox_inches='tight', pad_inches=0, transparent=True)

# Show the plot
plt.show()
# Out:
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df_primary' is your DataFrame
# Replace 'grouping_column' with the name of the column you want to group by
# Replace 'column_to_count' with the name of the column you want to count occurrences of
df_filtered = df_primary[df_primary['Metropolitan_Indicator_Desc'] != 'Unknown']

# Create a count plot
plt.figure(figsize=(10, 6))
sns.countplot(data=df_filtered, x='Metropolitan_Indicator_Desc', hue='US_Mexico_Border_County')

# Set the title and labels
plt.title('Count of Occurrences by Group')
plt.xlabel('Grouping Column')
plt.ylabel('Count')

# Rotate the x-axis labels for better readability if necessary
plt.xticks(rotation=45)

# Show the plot
plt.show()
# Out:
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Define your custom color scheme
palette = ['#ecb462', '#d35635', '#4da1ad', '#212121']

df_filtered = df_primary[df_primary['US_Mexico_Border_County'] != 'U']
df_filtered = df_filtered[df_filtered['US_Mexico_Border_County'] != 'Not Applicable']


# Calculate the average HPSA_Score for each region
avg_hpsa_score_per_region = df_filtered.groupby('US_Mexico_Border_County')['HPSA_Score'].mean().reset_index()

# Create a bar chart
plt.figure(figsize=(12, 7))
sns.barplot(x='US_Mexico_Border_County', y='HPSA_Score', data=avg_hpsa_score_per_region)

# Set the title and labels
plt.title('Average HPSA Score by US Mexico Border Indicator')
plt.xlabel('Rural_Status_Desc')
plt.ylabel('Average HPSA Score')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()
# Out:
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define your custom color scheme
palette = ['#ecb462', '#d35635', '#4da1ad', '#212121']

# Assuming 'df_primary' is your DataFrame and it contains 'Metropolitan_Indicator_Desc' column
# Filter out 'Unknown' and 'Not Applicable' from the 'Rural_Status_Desc' column
df_filtered = df_primary[~df_primary['Rural_Status_Desc'].isin(['Unknown','Not Applicable'])]

# Create a box plot
plt.figure(figsize=(12, 7))
sns.boxplot(x='Rural_Status_Desc', y='HPSA_Score', data=df_filtered, palette=palette)

# Set the title and labels
plt.title('Distribution of HPSA Score by Rural Status Description')
plt.xlabel('Rural Status Description')
plt.ylabel('HPSA Score')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()


# Show the plot
plt.show()
# Out:
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define your custom color scheme
palette = ['#ecb462', '#d35635', '#4da1ad', '#212121']

# Assuming 'df_primary' is your DataFrame and it contains 'Metropolitan_Indicator_Desc' column
# Filter out 'Unknown' and 'Not Applicable' from the 'Metropolitan_Indicator_Desc' column
df_filtered = df_primary[~df_primary['Rural_Status_Desc'].isin(['Unknown','Not Applicable'])]

# Calculate the average HPSA_Score for each Metropolitan Indicator Description
avg_hpsa_score_per_metropolitan = df_filtered.groupby('Rural_Status_Desc')['Designation_Pop'].mean().reset_index()

# Create a bar chart
plt.figure(figsize=(12, 7))
sns.barplot(x='Rural_Status_Desc', y='Designation_Pop', data=avg_hpsa_score_per_metropolitan, palette=palette)

# Set the title and labels
plt.title('Average Population by Rural Status Description')
plt.xlabel('Rural Status Description')
plt.ylabel('Average Designation_Pop')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/meenalgaba/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
